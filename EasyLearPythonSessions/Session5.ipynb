# %%
num = 10

numlist = [1,2,3,4,5,5,7]

# %%
numlist[0] = 10
numlist
# Out:
# [10, 2, 3, 4, 5, 5, 7]

# %%
#          0      1   2    3        4  
varList = ["name",123,True,764.213, [1,"af",True, [1,2],"wer"]]

varList[4][3][1]
varList[-1] = "abc"

# %%
mytuple = ("name",123,True,764.213, [1,"af",True, (1,2),"wer"],"name",123)
mytuple[4][3][1]
varList[-1] = "abc"
# mytuple[4][3][1] = "DD"

# %%
my_set = { 10,20,40,10,50,60,70,20 } #count was 7 with index starting at 0, total len is 8, after auto removal of deuplicates, len = 6
my_set1 = { 40, 60, 80, 90 }

# my_set.add(100)

len(my_set)

union_set = my_set.union(my_set1)
len(union_set)
union_set.discard(90)
len(union_set)
# Out:
# 7

# %%
Choice = input("enter y/n:")

while Choice != "y" and Choice != "n":
    Choice = input("enter y/n:")

print(Choice)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 Choice = input("enter y/n:")
# ----> 3 while Choice != "y" or Choice != "n":
#       4     Choice = input("enter y/n:")
#       6 print(Choice)
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1481, in _pydevd_sys_monitoring_cython._line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1523, in _pydevd_sys_monitoring_cython._internal_line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1324, in _pydevd_sys_monitoring_cython._stop_on_breakpoint()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1961, in _pydevd_sys_monitoring_cython._do_wait_suspend()
#
# ...
