# %%
num = 10

numlist = [1,2,3,4,5,5,7]

# %%
numlist[0] = 10
numlist
# Out:
# [10, 2, 3, 4, 5, 5, 7]

# %%
#          0      1   2    3        4  
varList = ["name",123,True,764.213, [1,"af",True, [1,2],"wer"]]

varList[4][3][1]
varList[-1] = "abc"
varList
# Out:
# ['name', 123, True, 764.213, 'abc']

# %%
mytuple = ("name",123,True,764.213, [1,"af",True, (1,2),"wer"])
mytuple[4][3][1]
varList[-1] = "abc"
mytuple[4][3][1] = "DD"
mytuple
# Out:
# ('name', 123, True, 764.213, [1, 'af', True, (1, 2), 'wer'])
